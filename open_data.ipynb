# %%
import msgpack as mp
import msgpack_numpy as mpn
import numpy as np
import matplotlib.pyplot as plt

# %%
cpth = r"F:\CMC\Neuro Stimulator Project\data\456\CMAPdata6.msgpack"

# %%
f = open(cpth, "rb")
unpacker = mp.Unpacker(f, object_hook=mpn.decode)
data = []
for unpacked in unpacker:
    data.append(unpacked)
    # print(unpacked)
f.close()

# %%
plt.plot(np.array(data[3]))
# print(data)
